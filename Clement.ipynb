# %%
import pandas as pd
import numpy as np
df = pd.read_excel('donnees_insee_premiere_n1948.xlsx')
df.head()
# Out:
#   « Le trajet médian domicile-travail augmente de moitié en vingt ans pour les habitants du rural » - Insee Première n° 1948
# 0                                                NaN
# 1              Données des figures de la publication
# 2                                                NaN
# 3  Figure 1 - Répartition des actifs en emploi se...
# 4                                                NaN

# %%
df2=pd.read_excel('RPM2024-D1.xlsx')
df2
# Out:
#    Iref RPM 2024 - Dossier 1 « Un tiers des personnes à très bas revenus en 2003 le sont encore près de 20 ans plus tard »
# 0                                                 NaN
# 1               Données des figures de la publication
# 2                                                 NaN
# 3   Figure 1 - Répartition des types de revenu pri...
# 4                                                 NaN
# 5   Figure 2 - Caractéristiques sociodémographique...
# 6                                                 NaN
# 7   Figure 3 - Pyramide des âges selon les revenus...
# 8                                                 NaN
# 9   Figure 4a - Part des personnes à très bas reve...
# 10                                                NaN
# 11  Figure 4b - Part des personnes à très bas reve...
# 12                                                NaN
# 13  Figure 5a - Évolution des revenus avant redist...
# 14                                                NaN
# ...
