# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("Figure_4.csv")

# %%
df
# Out:
#                                  Code_commune_Insee_2022  \
# 0                                                  01002
# 1                                                  01004
# 2                                                  01005
# 3                                                  01006
# 4                                                  01007
# ...                                                  ...
# 34731                                              95682
# 34732                                              95690
# 34733  Lecture : en 2019, la moitié des actifs en emp...
# 34734  Champ : actifs en emploi résidant et travailla...
# 34735  Source : Insee, recensements de la population ...
#
#         Libelle_commune_2022  Population_active_emploi_1999  \
# 0      L'Abergement-de-Varey                           32.0
# 1          Ambérieu-en-Bugey                         4504.0
# 2        Ambérieux-en-Dombes                          568.0
# ...

# %%
df = df[df.Libelle_commune_2022.notna()]

# %%
df
# Out:
#       Code_commune_Insee_2022   Libelle_commune_2022  \
# 0                       01002  L'Abergement-de-Varey
# 1                       01004      Ambérieu-en-Bugey
# 2                       01005    Ambérieux-en-Dombes
# 3                       01006                Ambléon
# 4                       01007               Ambronay
# ...                       ...                    ...
# 34728                   95676     Villers-en-Arthies
# 34729                   95678          Villiers-Adam
# 34730                   95680        Villiers-le-Bel
# 34731                   95682        Villiers-le-Sec
# 34732                   95690    Wy-dit-Joli-Village
#
#        Population_active_emploi_1999  \
# 0                               32.0
# 1                             4504.0
# 2                              568.0
# 3                               28.0
# 4                              933.0
# ...                              ...
# 34728                          196.0
# ...

# %%
df = df[df.Population_active_emploi_2019.notna()]

# %%
df
# Out:
#       Code_commune_Insee_2022   Libelle_commune_2022  \
# 0                       01002  L'Abergement-de-Varey
# 1                       01004      Ambérieu-en-Bugey
# 2                       01005    Ambérieux-en-Dombes
# 3                       01006                Ambléon
# 4                       01007               Ambronay
# ...                       ...                    ...
# 34728                   95676     Villers-en-Arthies
# 34729                   95678          Villiers-Adam
# 34730                   95680        Villiers-le-Bel
# 34731                   95682        Villiers-le-Sec
# 34732                   95690    Wy-dit-Joli-Village
#
#        Population_active_emploi_1999  \
# 0                               32.0
# 1                             4504.0
# 2                              568.0
# 3                               28.0
# 4                              933.0
# ...                              ...
# 34728                          196.0
# ...
